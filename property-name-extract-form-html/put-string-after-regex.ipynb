# %%
import re

text = 'PrecontractualAssessmentReport.Property1 == % stuffs to PrecontractualAssessmentReport.dumbproperty'
result = re.sub(r"(PrecontractualAssessmentReport.[^\s]+)", r'\1+2nd', text)
print(result)
# Out:
# PrecontractualAssessmentReport.Property1+2nd == % stuffs to PrecontractualAssessmentReport.dumbproperty+2nd

# %%
target = "localizationObj"
new = []
contains = 0
#filename = "targetFile.txt"
#file = open(filename, encoding="utf8")
for line in open("car-pdf.txt", encoding="utf8").readlines():
    result = re.sub(r"(PrecontractualAssessmentReport.[^\s]+)", r'\1+2nd', line)
    print(result)
# Out:
#         <tr>
#
#             <td>
#
#                 <table width="100%">
#
#                     <td>
#
#                         <h1>
#
#                            <span> {{localizationObj.NEW.PCAR_IDENTIFICATION_CLIENT.APP_TITLE}}</span>
#
#                             <span class="slpc-workflow-dual-language">{{ localizationObj.NEW.PCAR_IDENTIFICATION_CLIENT.APP_TITLE_LOCAL }}</span>
#
#
#
#                         </h1>
#
#                     </td>
#
#                 </table>
#
#             </td>
#
#         </tr>
#
#         <!-- Section 1 -->
#
#         <tr>
#
#             <td>
#
#                 <table width=100% class="pdf-table">
#
#                     <td width=30%>
#
#                     <span>{{localizationObj.NEW.PCAR_IDENTIFICATION_CLIENT.APP_NUMBER}}</span>
#
#                     <span class="slpc-workflow-dual-language">{{ localizationObj.NEW.PCAR_IDENTIFICATION_CLIENT.APP_NUMBER_LOCAL }}</span>
#
#                     </td>
#
#                     <td>
#
# ...
