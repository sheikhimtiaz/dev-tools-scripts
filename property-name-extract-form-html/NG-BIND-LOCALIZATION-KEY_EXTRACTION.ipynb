# %%
target = "localizationObj"
new = []
contains = 0
#filename = "targetFile.txt"
#file = open(filename, encoding="utf8")
for line in open("targetFile.txt", encoding="utf8").readlines():
    indvStrings = line.split()
    for i in indvStrings:
        check = i[:15]
        if(check == target):
            for j in new:
                if i == j:
                    contains = 1
                    continue
            if contains == 0 :
                # print(new.count(i))
                new.append(i)
                print(i)
            contains = 0
# Out:
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.SUB_TITLE_BENEFICIAL
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_BENENFICIAL_CONTRACT
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_LIFE_INSURED}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_LIFE_INSURED
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_POLICYHOLDER}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_POLICYHOLDER
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_OTHER}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_OTHER
# localizationObj.COMMON_LOCALIZATION_DATA.SELECT_ONE
# localizationObj.COMMON_LOCALIZATION_DATA.SELECT_ONE_LOCAL
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.FIRST_INSURED_PERSON}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.FIRST_INSURED_PERSON
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.SECOND_INSURED_PERSON}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.SECOND_INSURED_PERSON
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_FIRST_POLICYHOLDER}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_FIRST_POLICYHOLDER
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_SECOND_POLICYHOLDER}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_SECOND_POLICYHOLDER
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_FAMILY
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_GIVEN_NAME
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_ALIASES
# localizationObj.COMMON_LOCALIZATION_DATA.LABEL_GENDER
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.RADIO_MALE}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.RADIO_MALE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.RADIO_FEMALE}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.RADIO_FEMALE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_ADDRESS
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_STREET
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_POST
# localizationObj.COMMON_LOCALIZATION_DATA.LABEL_COUNTRY
# localizationObj.COMMON_LOCALIZATION_DATA.LABEL_COUNTRY}}
# localizationObj.COMMON_LOCALIZATION_DATA.LABEL_NATIONALITY}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_DOB
# localizationObj.COMMON_LOCALIZATION_DATA.INVALID_DATE
# localizationObj.COMMON_LOCALIZATION_DATA.REQUIRED_MESSAGE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_PLACE_BIRTH
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_UNIQUE_DOC
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.CB_IDENTITY}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.CB_IDENTITY
# localizationObj.ALPHA_PLUS_JOINT_POLICYHOLDER_DETAILS.CB_NO
# localizationObj.COMMON_LOCALIZATION_DATA.TEXT_LENGTH_VALIDATION
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.CB_PASSPORT}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.CB_PASSPORT
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.CB_OTHER}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.CB_OTHER
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.NAME_OF_DOC
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.PLEASE_SPECIFY
# localizationObj.APP_PROCESS_BENEFICIAL_OWNER.LABEL_TAX_IDENTIFICATION_NUMBER
# localizationObj.APP_PROCESS_BENEFICIAL_OWNER.LABEL_TAX_RESIDENCE
# localizationObj.APP_PROCESS_BENEFICIAL_OWNER.LABEL_TAX_RESIDENCE}}
# localizationObj.APP_PROCESS_BENEFICIAL_OWNER.IF_NO_TIN
# localizationObj.APP_PROCESS_CORRESPONDENCE_ADDRESS.RADIO_A
# localizationObj.APP_PROCESS_CORRESPONDENCE_ADDRESS.RADIO_B
# localizationObj.APP_PROCESS_CORRESPONDENCE_ADDRESS.RADIO_C
# localizationObj.APP_PROCESS_BENEFICIAL_OWNER.PLEASE_EXPLAIN
# localizationObj.APP_PROCESS_BENEFICIAL_OWNER.CB_THE_POLICYHOLDER_CONFIRMS}}
# localizationObj.APP_PROCESS_BENEFICIAL_OWNER.CB_THE_POLICYHOLDER_CONFIRMS
# localizationObj.COMMON_LOCALIZATION_DATA.ADD_MORE}}
# localizationObj.COMMON_LOCALIZATION_DATA.REMOVE}}
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.POLICYHOLDER_RELATION
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.ADD_ANOTHER_BENEFICIAL
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.RADIO_YES
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.RADIO_NO
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.SUB_TITLE_REVOCABLE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_REVOCABLE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.SUB_TITLE_NOMINEE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.IN_ACCORDANCE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.I_UNDERSTAND_THAT
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_NOMINEE_NAME
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_NATIONAL_REGISTRATION
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_UNIQUE_ENTITY
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_SHARE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.ADD_ANOTHER_NOMINEE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.SUB_TITLE_WITNESS
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_NAME_WITNESS
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_REGISTRATION_PASSPORT
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_TELEPHONE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.ADD_ANOTHER_WITNESS
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.SUB_TITLE_TRUST
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_TRUST
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.IN_ACCORDANCE_TRUST
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.I_UNDERSTAND_THAT_TRUST
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_RELATION_NOMINEE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.SUB_TITLE_TRUSTEE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_TRUSTEE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_OTHER_PERSONS
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.LABEL_NAME_TRUSTEE
# localizationObj.ALPHA_PLUS_JOINT_AUTHORISED_RECEPIENT.ADD_ANOTHER_TRUSTEE
